# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutvikaneriya23/DADV/blob/main/DADV_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.shape
# Out:
# (27, 2)

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (26, 2)

# %%
x = df[['age']]

# %%
y = df[['bought_insurance']]

# %%
print(x.shape)
print(y.shape)
print(type(x))
print(type(y))
# Out:
# (26, 1)
# (26, 1)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19, 1)
# (7, 1)
# (19, 1)
# (7, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
m1 = LogisticRegression()
m1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Train Score : ",m1.score(x_train,y_train))
print("Test Score : ",m1.score(x_test,y_test))
# Out:
# Train Score :  0.8421052631578947
# Test Score :  0.8571428571428571

# %%
print("Coeeficient : ",m1.coef_)
print("Intercept : ",m1.intercept_)
# Out:
# Coeeficient :  [[0.1461897]]
# Intercept :  [-5.94934567]

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = m1.predict(x_test)
print(y_pred)
# Out:
# [1 0 0 1 0 1 0]

# %%
print("For 57 : ",m1.predict([[57]]))
print("\nFor 23 : ",m1.predict([[23]]))
# Out:
# For 57 :  [1]
#
# For 23 :  [0]

# %%
plt.scatter(x,y)
plt.plot(x,m1.predict(x),c="red")

# %%
sns.regplot(x=x,y=y,data=df,logistic=True)
# Out:
# <Axes: xlabel='age', ylabel='bought_insurance'>

# %%
m1.score(x_train,y_train)
# Out:
# 0.8421052631578947

# %%
m1.score(x_test,y_test)
# Out:
# 0.8571428571428571
