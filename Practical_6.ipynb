# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutvikaneriya23/DADV/blob/main/Practical_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/PlayCricket-6.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
df.shape
# Out:
# (14, 5)

# %%
df.isnull().sum()
# Out:
# outlook     0
# temp        0
# humidity    0
# windy       0
# play        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   outlook   14 non-null     object
#  1   temp      14 non-null     object
#  2   humidity  14 non-null     object
#  3   windy     14 non-null     bool
#  4   play      14 non-null     object
# dtypes: bool(1), object(4)
# memory usage: 594.0+ bytes

# %%
df.describe()
# Out:
#        outlook  temp humidity  windy play
# count       14    14       14     14   14
# unique       3     3        2      2    2
# top      sunny  mild     high  False  yes
# freq         5     6        7      8    9

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['outlook_n']=le.fit_transform(df['outlook'])
df['temp_n']=le.fit_transform(df['temp'])
df['humidity_n']=le.fit_transform(df['humidity'])
df['windy_n']=le.fit_transform(df['windy'])
df['play_n']=le.fit_transform(df['play'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outlook'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-24-1668524882.py in <cell line: 0>()
# ----> 1 df['outlook_n']=le.fit_transform(df['outlook'])
#       2 df['temp_n']=le.fit_transform(df['temp'])
#       3 df['humidity_n']=le.fit_transform(df['humidity'])
#       4 df['windy_n']=le.fit_transform(df['windy'])
#       5 df['play_n']=le.fit_transform(df['play'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'outlook'

# %%
df=pd.read_csv('/content/PlayCricket-6.csv') # Re-load the data
df['outlook_n']=le.fit_transform(df['outlook'])
df['temp_n']=le.fit_transform(df['temp'])
df['humidity_n']=le.fit_transform(df['humidity'])
df['windy_n']=le.fit_transform(df['windy'])
df['play_n']=le.fit_transform(df['play'])
df
# Out:
#      outlook  temp humidity  windy play  outlook_n  temp_n  humidity_n  \
# 0      sunny   hot     high  False   no          2       1           0
# 1      sunny   hot     high   True   no          2       1           0
# 2   overcast   hot     high  False  yes          0       1           0
# 3      rainy  mild     high  False  yes          1       2           0
# 4      rainy  cool   normal  False  yes          1       0           1
# 5      rainy  cool   normal   True   no          1       0           1
# 6   overcast  cool   normal   True  yes          0       0           1
# 7      sunny  mild     high  False   no          2       2           0
# 8      sunny  cool   normal  False  yes          2       0           1
# 9      rainy  mild   normal  False  yes          1       2           1
# 10     sunny  mild   normal   True  yes          2       2           1
# 11  overcast  mild     high   True  yes          0       2           0
# 12  overcast   hot   normal  False  yes          0       1           1
# 13     rainy  mild     high   True   no          1       2           0
#
#     windy_n  play_n
# 0         0       0
# 1         1       0
# 2         0       1
# 3         0       1
# 4         0       1
# 5         1       0
# 6         1       1
# 7         0       0
# 8         0       1
# 9         0       1
# 10        1       1
# 11        1       1
# 12        0       1
# 13        1       0

# %%
df=df.drop(['outlook','temp','humidity','windy','play'],axis='columns')
df
# Out:
#     outlook_n  temp_n  humidity_n  windy_n  play_n
# 0           2       1           0        0       0
# 1           2       1           0        1       0
# 2           0       1           0        0       1
# 3           1       2           0        0       1
# 4           1       0           1        0       1
# 5           1       0           1        1       0
# 6           0       0           1        1       1
# 7           2       2           0        0       0
# 8           2       0           1        0       1
# 9           1       2           1        0       1
# 10          2       2           1        1       1
# 11          0       2           0        1       1
# 12          0       1           1        0       1
# 13          1       2           0        1       0

# %%
x=df.drop('play_n',axis='columns')
y=df['play_n']

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[2,1,0,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
